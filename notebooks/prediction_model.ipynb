# %% [markdown]
# ## Prediction Model
# #### Import package

# %%
import datetime
import h5py
import numpy as np
import os
import pandas as pd
import pickle

from sklearn.ensemble import RandomForestRegressor

from catboost import CatBoostRegressor
from hyperopt import fmin, tpe, hp
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.model_selection import KFold
from xgboost import XGBRegressor

# %% [markdown]
# #### Read dataset

# %%
dataset_folder = os.getcwd() + '/../dataset/'
train = pd.read_csv('../dataset/2019-02-27_19-31_processed_train.csv', index_col=0)
test = pd.read_csv('../dataset/2019-02-27_19-31_processed_test.csv', index_col=0)

# %%
X = train.drop(['revenue'], axis=1).values
y = np.log(train.revenue.values + 1)
X_test = test.drop(['revenue'], axis=1).values

# %% [markdown]
# #### Set parameters

# %%
# RandomForestRegressor
params = {'n_jobs': 4,
          'random_state': 0,
          'n_estimators': hp.choice('n_estimators', [100, 250, 500, 750, 1000]),
          'max_depth': hp.choice('max_depth', np.arange(3, 15, dtype=int)),
          'max_features': hp.choice('max_features', ['auto', 'sqrt', 'log2']),
          'min_samples_split': hp.uniform('min_samples_split', 0, 0.5),
          'min_samples_leaf': hp.uniform('min_samples_leaf', 0, 0.5)}

# %%
# XGBRegressor
params = {'silent': True,
          'objective': 'reg:linear',
          'seed': 0,
          'n_estimators': hp.choice('n_estimators', [100, 250, 500, 750, 1000]),
          'max_depth': hp.choice('max_depth', np.arange(5, 15, dtype=int)),
          'learning_rate': hp.uniform('learning_rate', 0, 0.75),  
          'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
          'subsample': hp.uniform('subsample', 0.5, 1)}

# %%
# CatBoostRegressor
params = {'random_seed': 0,
          'early_stopping_rounds': 500,
          'eval_metric': 'RMSE',
          'logging_level': 'Silent',
          'n_estimators': 1000,
          'depth': hp.choice('depth', np.arange(3, 15, dtype=int)),
          'learning_rate': hp.uniform('learning_rate', 0, 0.75),
          'colsample_bylevel': hp.uniform('colsample_bylevel', 0.5, 1)}

# %%
# LGBMRegressor
params = {'seed': 0,
          'tree_learner_type': hp.choice('tree_learner_type', ['serial', 'feature', 'data', 'voting']),
          'n_estimators': hp.choice('n_estimators', [100, 250, 500, 750, 1000]),
          'num_leaves': hp.choice('num_leaves', [50, 100, 150, 200, 250, 500, 750, 1000]),
          'min_data_in_leaf' : hp.choice('min_data_in_leaf', [10, 20, 30, 40, 50, 100]),
          'max_depth': hp.choice('max_depth', np.arange(3, 15, dtype=int)),
          'learning_rate': hp.uniform('learning_rate', 0, 0.75),}

# %% [markdown]
# #### Define optimization function

# %%
def KfoldCV(args): 
    
    rmlse_score = list()
    kf = KFold(n_splits=4)
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model = RandomForestRegressor(**args)
        #model = CatBoostRegressor(**args)
        #model = LGBMRegressor(**args)
        #model = XGBRegressor(**args)
        model.fit(X_train, y_train)
        #model.fit(X_train, y_train, verbose=False)
        
        pred = model.predict(X_test)
        pred[pred < 0] = 0        
        
        rmlse_score.append(np.sqrt(mean_squared_error(pred, y_test)))
    
    return np.mean(rmlse_score)

# %% [markdown]
# #### Parameters of best prediction model

# %%
best = fmin(KfoldCV, params, algo=tpe.suggest, max_evals=10)
print("Best estimate parameters: ", best)
# Out:
# 100%|██████████| 10/10 [01:05<00:00,  6.54s/it, best loss: 2.426852888889002]
# Best estimate parameters:  {'max_features': 2, 'min_samples_leaf': 0.007496219809590587, 'n_estimators': 0, 'max_depth': 2, 'min_samples_split': 0.19018878860212296}

# %% [markdown]
# #### Define model based on the parameters found

# %% [raw]
# # Submission #001
# model = RandomForestRegressor(n_estimators=500,
#                               max_depth=9,
#                               min_samples_leaf=0.002,
#                               min_samples_split=0.027)

# %% [raw]
# # Submission #002
# model = RandomForestRegressor(n_estimators=500,
#                               max_depth=8,
#                               min_samples_leaf=0.004,
#                               min_samples_split=0.007)

# %% [raw]
# # Submission #003
# model = XGBRegressor(silent=False,
#                      scale_pos_weight=1,
#                      learning_rate=0.01,
#                      colsample_bytree = 0.4,
#                      subsample = 0.8,
#                      objective='reg:linear',
#                      n_estimators=500,
#                      reg_alpha = 0.3,
#                      max_depth=4,
#                      gamma=10)

# %% [raw]
# # Submission #004
# model = CatBoostRegressor(iterations=1000,
#                           eval_metric='RMSE',
#                           early_stopping_rounds=200,
#                           metric_period=None,
#                           depth=3,
#                           learning_rate=0.043,
#                           colsample_bylevel=0.153,
#                           bagging_temperature=0.063)

# %% [raw]
# # Submission #005
# model = XGBRegressor(silent=True,
#                      objective='reg:linear',
#                      n_estimators=500,
#                      learning_rate=0.021,
#                      colsample_bytree = 0.394,
#                      subsample = 0.466,
#                      max_depth=2)

# %%
# Submission #006
model = LGBMRegressor(n_estimators=500,
                      min_data_in_leaf=10, 
                      learning_rate=0.0100,
                      bagging_fraction=0.427,
                      max_depth=7,
                      num_leaves=250)

# %%
# Submission #007
model = CatBoostRegressor(iterations=1000,
                          eval_metric='RMSE',
                          early_stopping_rounds=200,
                          metric_period=None,
                          depth=8,
                          learning_rate=0.043,
                          colsample_bylevel=0.153,
                          bagging_temperature=0.063)

# %%
# Submission #008
model = XGBRegressor(silent=True,
                     objective='reg:linear', 
                     n_estimators=500,
                     learning_rate=0.021,  
                     colsample_bytree = 0.394,
                     subsample = 0.466,
                     max_depth=7)

# %%
# Submission #009
model_lgb = LGBMRegressor(n_estimators=500, min_data_in_leaf=10, learning_rate=0.0100,
                          bagging_fraction=0.427, max_depth=7, num_leaves=250)
model_cat = CatBoostRegressor(iterations=1000, eval_metric='RMSE', early_stopping_rounds=200,
                          metric_period=None, depth=8, learning_rate=0.043,
                          colsample_bylevel=0.153, bagging_temperature=0.063)
model_xgb = XGBRegressor(silent=True, objective='reg:linear', n_estimators=500,
                         learning_rate=0.021, colsample_bytree = 0.394, subsample = 0.466,
                         max_depth=7)

# %%
model_lgb.fit(X, y)
model_cat.fit(X, y)
model_xgb.fit(X, y)

pred_lgb = model_lgb.predict(X_test)
pred_cat = model_cat.predict(X_test)
pred_xgb = model_xgb.predict(X_test)
pred = (pred_lgb + pred_cat + pred_xgb) / 3
submission = (np.e ** pred - 1)
# Out:
# 0:	learn: 15.5916733	total: 18ms	remaining: 18s
# 1:	learn: 14.9647462	total: 37.5ms	remaining: 18.7s
# 2:	learn: 14.3510315	total: 48.7ms	remaining: 16.2s
# 3:	learn: 13.7635742	total: 61ms	remaining: 15.2s
# 4:	learn: 13.2116722	total: 80ms	remaining: 15.9s
# 5:	learn: 12.6847103	total: 88.7ms	remaining: 14.7s
# 6:	learn: 12.1769509	total: 94.2ms	remaining: 13.4s
# 7:	learn: 11.6989610	total: 106ms	remaining: 13.2s
# 8:	learn: 11.2285461	total: 116ms	remaining: 12.7s
# 9:	learn: 10.7815237	total: 124ms	remaining: 12.3s
# 10:	learn: 10.3605104	total: 138ms	remaining: 12.4s
# 11:	learn: 9.9514694	total: 143ms	remaining: 11.8s
# 12:	learn: 9.5623842	total: 155ms	remaining: 11.8s
# 13:	learn: 9.1919346	total: 167ms	remaining: 11.7s
# 14:	learn: 8.8330996	total: 176ms	remaining: 11.6s
# 15:	learn: 8.4917577	total: 180ms	remaining: 11s
# 16:	learn: 8.1822391	total: 187ms	remaining: 10.8s
# 17:	learn: 7.8724586	total: 190ms	remaining: 10.4s
# 18:	learn: 7.5794074	total: 198ms	remaining: 10.2s
# 19:	learn: 7.3023183	total: 210ms	remaining: 10.3s
# 20:	learn: 7.0379201	total: 223ms	remaining: 10.4s
# 21:	learn: 6.7828482	total: 248ms	remaining: 11s
# 22:	learn: 6.5378184	total: 287ms	remaining: 12.2s
# 23:	learn: 6.3037554	total: 317ms	remaining: 12.9s
# 24:	learn: 6.0766263	total: 329ms	remaining: 12.8s
# 25:	learn: 5.8654957	total: 340ms	remaining: 12.7s
# 26:	learn: 5.6660870	total: 343ms	remaining: 12.4s
# 27:	learn: 5.4773883	total: 349ms	remaining: 12.1s
# 28:	learn: 5.3015895	total: 362ms	remaining: 12.1s
# 29:	learn: 5.1328335	total: 369ms	remaining: 11.9s
# 30:	learn: 4.9664034	total: 379ms	remaining: 11.9s
# 31:	learn: 4.8029254	total: 386ms	remaining: 11.7s
# 32:	learn: 4.6549400	total: 390ms	remaining: 11.4s
# 33:	learn: 4.5203798	total: 397ms	remaining: 11.3s
# 34:	learn: 4.3857154	total: 411ms	remaining: 11.3s
# 35:	learn: 4.2649562	total: 419ms	remaining: 11.2s
# 36:	learn: 4.1500500	total: 435ms	remaining: 11.3s
# 37:	learn: 4.0332516	total: 445ms	remaining: 11.3s
# 38:	learn: 3.9197386	total: 464ms	remaining: 11.4s
# 39:	learn: 3.8167422	total: 494ms	remaining: 11.9s
# 40:	learn: 3.7166098	total: 498ms	remaining: 11.6s
# 41:	learn: 3.6183618	total: 527ms	remaining: 12s
# 42:	learn: 3.5353006	total: 537ms	remaining: 12s
# 43:	learn: 3.4521691	total: 550ms	remaining: 11.9s
# 44:	learn: 3.3748705	total: 557ms	remaining: 11.8s
# 45:	learn: 3.2982518	total: 565ms	remaining: 11.7s
# 46:	learn: 3.2343793	total: 573ms	remaining: 11.6s
# 47:	learn: 3.1659833	total: 584ms	remaining: 11.6s
# 48:	learn: 3.1051824	total: 593ms	remaining: 11.5s
# 49:	learn: 3.0453511	total: 606ms	remaining: 11.5s
# 50:	learn: 2.9933967	total: 613ms	remaining: 11.4s
# 51:	learn: 2.9363792	total: 629ms	remaining: 11.5s
# 52:	learn: 2.8825667	total: 643ms	remaining: 11.5s
# 53:	learn: 2.8342090	total: 664ms	remaining: 11.6s
# 54:	learn: 2.7877021	total: 726ms	remaining: 12.5s
# 55:	learn: 2.7490330	total: 749ms	remaining: 12.6s
# 56:	learn: 2.7143945	total: 764ms	remaining: 12.6s
# 57:	learn: 2.6791973	total: 777ms	remaining: 12.6s
# 58:	learn: 2.6450676	total: 786ms	remaining: 12.5s
# 59:	learn: 2.6136641	total: 801ms	remaining: 12.6s
# 60:	learn: 2.5813018	total: 816ms	remaining: 12.6s
# 61:	learn: 2.5517757	total: 831ms	remaining: 12.6s
# 62:	learn: 2.5240471	total: 853ms	remaining: 12.7s
# 63:	learn: 2.5015639	total: 871ms	remaining: 12.7s
# 64:	learn: 2.4742905	total: 908ms	remaining: 13.1s
# 65:	learn: 2.4501159	total: 926ms	remaining: 13.1s
# 66:	learn: 2.4272347	total: 943ms	remaining: 13.1s
# 67:	learn: 2.4060983	total: 955ms	remaining: 13.1s
# 68:	learn: 2.3906472	total: 966ms	remaining: 13s
# 69:	learn: 2.3685817	total: 976ms	remaining: 13s
# 70:	learn: 2.3503106	total: 988ms	remaining: 12.9s
# 71:	learn: 2.3285708	total: 1000ms	remaining: 12.9s
# 72:	learn: 2.3100797	total: 1.01s	remaining: 12.8s
# 73:	learn: 2.2938668	total: 1.02s	remaining: 12.8s
# 74:	learn: 2.2844085	total: 1.02s	remaining: 12.6s
# 75:	learn: 2.2663582	total: 1.04s	remaining: 12.6s
# 76:	learn: 2.2544182	total: 1.04s	remaining: 12.5s
# 77:	learn: 2.2441695	total: 1.05s	remaining: 12.4s
# 78:	learn: 2.2312326	total: 1.06s	remaining: 12.4s
# 79:	learn: 2.2207946	total: 1.1s	remaining: 12.6s
# 80:	learn: 2.2062409	total: 1.12s	remaining: 12.7s
# 81:	learn: 2.1957214	total: 1.13s	remaining: 12.7s
# 82:	learn: 2.1846122	total: 1.15s	remaining: 12.7s
# 83:	learn: 2.1730634	total: 1.16s	remaining: 12.7s
# 84:	learn: 2.1614332	total: 1.18s	remaining: 12.7s
# 85:	learn: 2.1542086	total: 1.19s	remaining: 12.6s
# 86:	learn: 2.1447614	total: 1.2s	remaining: 12.6s
# 87:	learn: 2.1379719	total: 1.2s	remaining: 12.5s
# 88:	learn: 2.1277357	total: 1.22s	remaining: 12.5s
# 89:	learn: 2.1192628	total: 1.25s	remaining: 12.7s
# 90:	learn: 2.1131896	total: 1.3s	remaining: 13s
# 91:	learn: 2.1052471	total: 1.35s	remaining: 13.3s
# 92:	learn: 2.0969298	total: 1.38s	remaining: 13.4s
# 93:	learn: 2.0898370	total: 1.39s	remaining: 13.4s
# 94:	learn: 2.0798609	total: 1.41s	remaining: 13.4s
# 95:	learn: 2.0729061	total: 1.42s	remaining: 13.3s
# 96:	learn: 2.0659421	total: 1.43s	remaining: 13.3s
# 97:	learn: 2.0587811	total: 1.44s	remaining: 13.2s
# 98:	learn: 2.0514170	total: 1.45s	remaining: 13.2s
# 99:	learn: 2.0461821	total: 1.45s	remaining: 13s
# 100:	learn: 2.0410630	total: 1.46s	remaining: 13s
# 101:	learn: 2.0355401	total: 1.48s	remaining: 13s
# 102:	learn: 2.0303006	total: 1.52s	remaining: 13.3s
# 103:	learn: 2.0275522	total: 1.53s	remaining: 13.2s
# 104:	learn: 2.0235610	total: 1.56s	remaining: 13.3s
# 105:	learn: 2.0228475	total: 1.57s	remaining: 13.2s
# 106:	learn: 2.0170684	total: 1.58s	remaining: 13.2s
# 107:	learn: 2.0157881	total: 1.59s	remaining: 13.2s
# 108:	learn: 2.0126402	total: 1.6s	remaining: 13.1s
# 109:	learn: 2.0116905	total: 1.61s	remaining: 13s
# 110:	learn: 2.0066748	total: 1.62s	remaining: 13s
# 111:	learn: 2.0006082	total: 1.63s	remaining: 12.9s
# 112:	learn: 1.9954881	total: 1.64s	remaining: 12.9s
# 113:	learn: 1.9926749	total: 1.65s	remaining: 12.8s
# 114:	learn: 1.9888329	total: 1.66s	remaining: 12.8s
# 115:	learn: 1.9845508	total: 1.68s	remaining: 12.8s
# 116:	learn: 1.9828930	total: 1.73s	remaining: 13.1s
# 117:	learn: 1.9807279	total: 1.75s	remaining: 13.1s
# 118:	learn: 1.9762901	total: 1.77s	remaining: 13.1s
# 119:	learn: 1.9741873	total: 1.79s	remaining: 13.1s
# 120:	learn: 1.9717517	total: 1.8s	remaining: 13.1s
# 121:	learn: 1.9682498	total: 1.81s	remaining: 13s
# 122:	learn: 1.9650273	total: 1.82s	remaining: 13s
# 123:	learn: 1.9608472	total: 1.83s	remaining: 12.9s
# 124:	learn: 1.9574603	total: 1.84s	remaining: 12.9s
# 125:	learn: 1.9557965	total: 1.85s	remaining: 12.9s
# 126:	learn: 1.9525541	total: 1.86s	remaining: 12.8s
# 127:	learn: 1.9493094	total: 1.88s	remaining: 12.8s
# 128:	learn: 1.9460385	total: 1.9s	remaining: 12.8s
# 129:	learn: 1.9390143	total: 1.94s	remaining: 13s
# 130:	learn: 1.9353742	total: 1.97s	remaining: 13.1s
# 131:	learn: 1.9334751	total: 2s	remaining: 13.2s
# 132:	learn: 1.9305872	total: 2.02s	remaining: 13.2s
# 133:	learn: 1.9274058	total: 2.04s	remaining: 13.2s
# 134:	learn: 1.9230936	total: 2.05s	remaining: 13.2s
# 135:	learn: 1.9217463	total: 2.06s	remaining: 13.1s
# 136:	learn: 1.9194025	total: 2.07s	remaining: 13.1s
# 137:	learn: 1.9176921	total: 2.08s	remaining: 13s
# 138:	learn: 1.9153696	total: 2.09s	remaining: 13s
# 139:	learn: 1.9109070	total: 2.12s	remaining: 13s
# 140:	learn: 1.9085966	total: 2.13s	remaining: 13s
# 141:	learn: 1.9068089	total: 2.14s	remaining: 12.9s
# 142:	learn: 1.9042028	total: 2.15s	remaining: 12.9s
# 143:	learn: 1.9020528	total: 2.16s	remaining: 12.8s
# 144:	learn: 1.9005813	total: 2.17s	remaining: 12.8s
# 145:	learn: 1.8983911	total: 2.18s	remaining: 12.7s
# 146:	learn: 1.8976839	total: 2.19s	remaining: 12.7s
# 147:	learn: 1.8923203	total: 2.2s	remaining: 12.7s
# 148:	learn: 1.8903049	total: 2.21s	remaining: 12.6s
# 149:	learn: 1.8891280	total: 2.22s	remaining: 12.6s
# 150:	learn: 1.8868533	total: 2.23s	remaining: 12.5s
# 151:	learn: 1.8849260	total: 2.24s	remaining: 12.5s
# 152:	learn: 1.8799045	total: 2.25s	remaining: 12.5s
# 153:	learn: 1.8783996	total: 2.26s	remaining: 12.4s
# 154:	learn: 1.8765627	total: 2.29s	remaining: 12.5s
# 155:	learn: 1.8744258	total: 2.3s	remaining: 12.4s
# 156:	learn: 1.8732557	total: 2.31s	remaining: 12.4s
# 157:	learn: 1.8692605	total: 2.34s	remaining: 12.5s
# 158:	learn: 1.8664984	total: 2.35s	remaining: 12.4s
# 159:	learn: 1.8662214	total: 2.35s	remaining: 12.3s
# 160:	learn: 1.8656548	total: 2.36s	remaining: 12.3s
# 161:	learn: 1.8627680	total: 2.37s	remaining: 12.2s
# 162:	learn: 1.8602324	total: 2.38s	remaining: 12.2s
# 163:	learn: 1.8589980	total: 2.39s	remaining: 12.2s
# 164:	learn: 1.8588328	total: 2.4s	remaining: 12.1s
# 165:	learn: 1.8572734	total: 2.41s	remaining: 12.1s
# 166:	learn: 1.8562972	total: 2.42s	remaining: 12.1s
# 167:	learn: 1.8553183	total: 2.43s	remaining: 12s
# 168:	learn: 1.8532068	total: 2.45s	remaining: 12s
# 169:	learn: 1.8512541	total: 2.46s	remaining: 12s
# 170:	learn: 1.8509031	total: 2.47s	remaining: 12s
# 171:	learn: 1.8499920	total: 2.48s	remaining: 11.9s
# 172:	learn: 1.8488877	total: 2.49s	remaining: 11.9s
# 173:	learn: 1.8482254	total: 2.49s	remaining: 11.8s
# 174:	learn: 1.8471355	total: 2.5s	remaining: 11.8s
# 175:	learn: 1.8470891	total: 2.51s	remaining: 11.8s
# 176:	learn: 1.8465002	total: 2.54s	remaining: 11.8s
# 177:	learn: 1.8418561	total: 2.58s	remaining: 11.9s
# 178:	learn: 1.8403630	total: 2.6s	remaining: 11.9s
# 179:	learn: 1.8393627	total: 2.62s	remaining: 11.9s
# 180:	learn: 1.8380440	total: 2.63s	remaining: 11.9s
# 181:	learn: 1.8354153	total: 2.64s	remaining: 11.9s
# 182:	learn: 1.8346812	total: 2.65s	remaining: 11.8s
# 183:	learn: 1.8338721	total: 2.66s	remaining: 11.8s
# 184:	learn: 1.8338670	total: 2.67s	remaining: 11.7s
# 185:	learn: 1.8329853	total: 2.67s	remaining: 11.7s
# 186:	learn: 1.8324527	total: 2.67s	remaining: 11.6s
# 187:	learn: 1.8313386	total: 2.68s	remaining: 11.6s
# 188:	learn: 1.8280910	total: 2.69s	remaining: 11.5s
# 189:	learn: 1.8247914	total: 2.71s	remaining: 11.5s
# 190:	learn: 1.8247843	total: 2.71s	remaining: 11.5s
# 191:	learn: 1.8227344	total: 2.74s	remaining: 11.5s
# 192:	learn: 1.8211200	total: 2.75s	remaining: 11.5s
# 193:	learn: 1.8194325	total: 2.77s	remaining: 11.5s
# 194:	learn: 1.8187891	total: 2.8s	remaining: 11.5s
# 195:	learn: 1.8160119	total: 2.81s	remaining: 11.5s
# 196:	learn: 1.8147991	total: 2.82s	remaining: 11.5s
# 197:	learn: 1.8143551	total: 2.83s	remaining: 11.5s
# 198:	learn: 1.8133302	total: 2.84s	remaining: 11.4s
# 199:	learn: 1.8101129	total: 2.85s	remaining: 11.4s
# 200:	learn: 1.8082039	total: 2.86s	remaining: 11.4s
# 201:	learn: 1.8076679	total: 2.87s	remaining: 11.3s
# 202:	learn: 1.8072175	total: 2.88s	remaining: 11.3s
# 203:	learn: 1.8056092	total: 2.88s	remaining: 11.3s
# 204:	learn: 1.8027547	total: 2.9s	remaining: 11.2s
# 205:	learn: 1.8017669	total: 2.92s	remaining: 11.2s
# 206:	learn: 1.7993903	total: 2.94s	remaining: 11.3s
# 207:	learn: 1.7966061	total: 2.95s	remaining: 11.2s
# 208:	learn: 1.7959530	total: 2.96s	remaining: 11.2s
# 209:	learn: 1.7959519	total: 2.97s	remaining: 11.2s
# 210:	learn: 1.7956738	total: 2.97s	remaining: 11.1s
# 211:	learn: 1.7925971	total: 2.98s	remaining: 11.1s
# 212:	learn: 1.7922319	total: 2.99s	remaining: 11s
# 213:	learn: 1.7911884	total: 3s	remaining: 11s
# 214:	learn: 1.7900582	total: 3.01s	remaining: 11s
# 215:	learn: 1.7880633	total: 3.02s	remaining: 11s
# 216:	learn: 1.7874882	total: 3.03s	remaining: 10.9s
# 217:	learn: 1.7870618	total: 3.04s	remaining: 10.9s
# 218:	learn: 1.7865497	total: 3.05s	remaining: 10.9s
# 219:	learn: 1.7855360	total: 3.06s	remaining: 10.9s
# 220:	learn: 1.7840246	total: 3.07s	remaining: 10.8s
# 221:	learn: 1.7832340	total: 3.08s	remaining: 10.8s
# 222:	learn: 1.7816736	total: 3.1s	remaining: 10.8s
# 223:	learn: 1.7807467	total: 3.11s	remaining: 10.8s
# 224:	learn: 1.7774509	total: 3.12s	remaining: 10.8s
# 225:	learn: 1.7773019	total: 3.13s	remaining: 10.7s
# 226:	learn: 1.7767445	total: 3.15s	remaining: 10.7s
# 227:	learn: 1.7736718	total: 3.16s	remaining: 10.7s
# 228:	learn: 1.7701208	total: 3.17s	remaining: 10.7s
# 229:	learn: 1.7687835	total: 3.19s	remaining: 10.7s
# 230:	learn: 1.7687641	total: 3.19s	remaining: 10.6s
# 231:	learn: 1.7685182	total: 3.2s	remaining: 10.6s
# 232:	learn: 1.7668467	total: 3.21s	remaining: 10.6s
# 233:	learn: 1.7663993	total: 3.22s	remaining: 10.5s
# 234:	learn: 1.7650693	total: 3.23s	remaining: 10.5s
# 235:	learn: 1.7646944	total: 3.24s	remaining: 10.5s
# 236:	learn: 1.7636195	total: 3.25s	remaining: 10.5s
# 237:	learn: 1.7610526	total: 3.26s	remaining: 10.4s
# 238:	learn: 1.7604156	total: 3.27s	remaining: 10.4s
# 239:	learn: 1.7593675	total: 3.27s	remaining: 10.4s
# 240:	learn: 1.7575132	total: 3.29s	remaining: 10.4s
# 241:	learn: 1.7573818	total: 3.29s	remaining: 10.3s
# 242:	learn: 1.7571626	total: 3.3s	remaining: 10.3s
# 243:	learn: 1.7561902	total: 3.31s	remaining: 10.3s
# 244:	learn: 1.7557785	total: 3.33s	remaining: 10.3s
# 245:	learn: 1.7556198	total: 3.34s	remaining: 10.2s
# 246:	learn: 1.7540003	total: 3.36s	remaining: 10.3s
# 247:	learn: 1.7509063	total: 3.37s	remaining: 10.2s
# 248:	learn: 1.7505931	total: 3.38s	remaining: 10.2s
# 249:	learn: 1.7498107	total: 3.39s	remaining: 10.2s
# 250:	learn: 1.7485889	total: 3.39s	remaining: 10.1s
# 251:	learn: 1.7483603	total: 3.4s	remaining: 10.1s
# 252:	learn: 1.7462190	total: 3.41s	remaining: 10.1s
# 253:	learn: 1.7447281	total: 3.42s	remaining: 10s
# 254:	learn: 1.7443842	total: 3.43s	remaining: 10s
# 255:	learn: 1.7436178	total: 3.44s	remaining: 10s
# 256:	learn: 1.7434783	total: 3.45s	remaining: 9.97s
# 257:	learn: 1.7434744	total: 3.45s	remaining: 9.92s
# 258:	learn: 1.7432112	total: 3.46s	remaining: 9.89s
# 259:	learn: 1.7430300	total: 3.47s	remaining: 9.87s
# 260:	learn: 1.7423541	total: 3.5s	remaining: 9.9s
# 261:	learn: 1.7422916	total: 3.5s	remaining: 9.86s
# 262:	learn: 1.7404568	total: 3.52s	remaining: 9.87s
# 263:	learn: 1.7401566	total: 3.54s	remaining: 9.86s
# 264:	learn: 1.7385244	total: 3.56s	remaining: 9.89s
# 265:	learn: 1.7383362	total: 3.58s	remaining: 9.87s
# 266:	learn: 1.7363500	total: 3.59s	remaining: 9.85s
# 267:	learn: 1.7361213	total: 3.6s	remaining: 9.82s
# 268:	learn: 1.7359282	total: 3.6s	remaining: 9.79s
# 269:	learn: 1.7358066	total: 3.61s	remaining: 9.75s
# 270:	learn: 1.7354611	total: 3.61s	remaining: 9.72s
# 271:	learn: 1.7351651	total: 3.62s	remaining: 9.69s
# 272:	learn: 1.7322328	total: 3.63s	remaining: 9.66s
# 273:	learn: 1.7320931	total: 3.64s	remaining: 9.64s
# 274:	learn: 1.7313650	total: 3.65s	remaining: 9.61s
# 275:	learn: 1.7303768	total: 3.65s	remaining: 9.59s
# 276:	learn: 1.7302820	total: 3.66s	remaining: 9.55s
# 277:	learn: 1.7276584	total: 3.67s	remaining: 9.53s
# 278:	learn: 1.7272520	total: 3.68s	remaining: 9.5s
# 279:	learn: 1.7249455	total: 3.69s	remaining: 9.49s
# 280:	learn: 1.7248887	total: 3.69s	remaining: 9.46s
# 281:	learn: 1.7248871	total: 3.7s	remaining: 9.42s
# 282:	learn: 1.7248398	total: 3.7s	remaining: 9.39s
# 283:	learn: 1.7247996	total: 3.71s	remaining: 9.35s
# 284:	learn: 1.7246679	total: 3.72s	remaining: 9.33s
# 285:	learn: 1.7241745	total: 3.73s	remaining: 9.31s
# 286:	learn: 1.7236378	total: 3.74s	remaining: 9.3s
# 287:	learn: 1.7234163	total: 3.75s	remaining: 9.28s
# 288:	learn: 1.7232656	total: 3.77s	remaining: 9.27s
# 289:	learn: 1.7201579	total: 3.79s	remaining: 9.27s
# 290:	learn: 1.7171964	total: 3.79s	remaining: 9.24s
# 291:	learn: 1.7169710	total: 3.8s	remaining: 9.21s
# 292:	learn: 1.7167425	total: 3.81s	remaining: 9.19s
# 293:	learn: 1.7167418	total: 3.81s	remaining: 9.16s
# 294:	learn: 1.7140488	total: 3.82s	remaining: 9.14s
# 295:	learn: 1.7139738	total: 3.83s	remaining: 9.1s
# 296:	learn: 1.7136791	total: 3.84s	remaining: 9.09s
# 297:	learn: 1.7132856	total: 3.85s	remaining: 9.06s
# 298:	learn: 1.7102731	total: 3.86s	remaining: 9.05s
# 299:	learn: 1.7101206	total: 3.87s	remaining: 9.03s
# 300:	learn: 1.7088083	total: 3.88s	remaining: 9.01s
# 301:	learn: 1.7056462	total: 3.89s	remaining: 8.99s
# 302:	learn: 1.7052165	total: 3.9s	remaining: 8.97s
# 303:	learn: 1.7037130	total: 3.91s	remaining: 8.94s
# 304:	learn: 1.7023683	total: 3.91s	remaining: 8.91s
# 305:	learn: 1.7020408	total: 3.92s	remaining: 8.89s
# 306:	learn: 1.7020292	total: 3.92s	remaining: 8.86s
# 307:	learn: 1.7017373	total: 3.94s	remaining: 8.85s
# 308:	learn: 1.7016837	total: 3.95s	remaining: 8.83s
# 309:	learn: 1.6998119	total: 3.96s	remaining: 8.83s
# 310:	learn: 1.6997674	total: 3.98s	remaining: 8.81s
# 311:	learn: 1.6991635	total: 3.99s	remaining: 8.79s
# 312:	learn: 1.6988912	total: 4s	remaining: 8.78s
# 313:	learn: 1.6987908	total: 4.01s	remaining: 8.76s
# 314:	learn: 1.6985734	total: 4.01s	remaining: 8.73s
# 315:	learn: 1.6960466	total: 4.03s	remaining: 8.72s
# 316:	learn: 1.6949882	total: 4.04s	remaining: 8.69s
# 317:	learn: 1.6949765	total: 4.04s	remaining: 8.66s
# 318:	learn: 1.6948857	total: 4.05s	remaining: 8.64s
# 319:	learn: 1.6948208	total: 4.05s	remaining: 8.61s
# 320:	learn: 1.6948109	total: 4.05s	remaining: 8.57s
# 321:	learn: 1.6945695	total: 4.06s	remaining: 8.56s
# 322:	learn: 1.6919521	total: 4.08s	remaining: 8.54s
# 323:	learn: 1.6917685	total: 4.09s	remaining: 8.53s
# 324:	learn: 1.6898549	total: 4.1s	remaining: 8.51s
# 325:	learn: 1.6871501	total: 4.11s	remaining: 8.5s
# 326:	learn: 1.6870452	total: 4.12s	remaining: 8.47s
# 327:	learn: 1.6865283	total: 4.12s	remaining: 8.45s
# 328:	learn: 1.6837802	total: 4.13s	remaining: 8.43s
# 329:	learn: 1.6819911	total: 4.15s	remaining: 8.43s
# 330:	learn: 1.6815617	total: 4.17s	remaining: 8.42s
# 331:	learn: 1.6801732	total: 4.19s	remaining: 8.43s
# 332:	learn: 1.6794676	total: 4.2s	remaining: 8.42s
# 333:	learn: 1.6794139	total: 4.21s	remaining: 8.39s
# 334:	learn: 1.6789384	total: 4.22s	remaining: 8.37s
# 335:	learn: 1.6783326	total: 4.23s	remaining: 8.36s
# 336:	learn: 1.6773779	total: 4.24s	remaining: 8.35s
# 337:	learn: 1.6751533	total: 4.25s	remaining: 8.33s
# 338:	learn: 1.6733727	total: 4.26s	remaining: 8.31s
# 339:	learn: 1.6730809	total: 4.27s	remaining: 8.3s
# 340:	learn: 1.6711315	total: 4.29s	remaining: 8.29s
# 341:	learn: 1.6698825	total: 4.3s	remaining: 8.28s
# 342:	learn: 1.6681649	total: 4.32s	remaining: 8.28s
# 343:	learn: 1.6658576	total: 4.34s	remaining: 8.28s
# 344:	learn: 1.6634883	total: 4.36s	remaining: 8.28s
# 345:	learn: 1.6633330	total: 4.38s	remaining: 8.28s
# 346:	learn: 1.6627786	total: 4.39s	remaining: 8.26s
# 347:	learn: 1.6618910	total: 4.4s	remaining: 8.25s
# 348:	learn: 1.6618180	total: 4.41s	remaining: 8.23s
# 349:	learn: 1.6609210	total: 4.42s	remaining: 8.21s
# 350:	learn: 1.6603177	total: 4.43s	remaining: 8.19s
# 351:	learn: 1.6588394	total: 4.44s	remaining: 8.17s
# 352:	learn: 1.6585262	total: 4.45s	remaining: 8.16s
# 353:	learn: 1.6580806	total: 4.46s	remaining: 8.15s
# 354:	learn: 1.6575474	total: 4.47s	remaining: 8.13s
# 355:	learn: 1.6573826	total: 4.49s	remaining: 8.11s
# 356:	learn: 1.6573302	total: 4.49s	remaining: 8.09s
# 357:	learn: 1.6562976	total: 4.5s	remaining: 8.08s
# 358:	learn: 1.6534649	total: 4.52s	remaining: 8.06s
# 359:	learn: 1.6518583	total: 4.52s	remaining: 8.04s
# 360:	learn: 1.6498364	total: 4.54s	remaining: 8.03s
# 361:	learn: 1.6491204	total: 4.55s	remaining: 8.02s
# 362:	learn: 1.6490879	total: 4.57s	remaining: 8.01s
# 363:	learn: 1.6488933	total: 4.58s	remaining: 8.01s
# 364:	learn: 1.6486990	total: 4.6s	remaining: 8s
# 365:	learn: 1.6467658	total: 4.61s	remaining: 7.98s
# 366:	learn: 1.6455532	total: 4.62s	remaining: 7.96s
# 367:	learn: 1.6453179	total: 4.63s	remaining: 7.95s
# 368:	learn: 1.6448385	total: 4.64s	remaining: 7.93s
# 369:	learn: 1.6446064	total: 4.65s	remaining: 7.92s
# 370:	learn: 1.6445630	total: 4.66s	remaining: 7.89s
# 371:	learn: 1.6436564	total: 4.67s	remaining: 7.88s
# 372:	learn: 1.6433143	total: 4.68s	remaining: 7.87s
# 373:	learn: 1.6428607	total: 4.69s	remaining: 7.85s
# 374:	learn: 1.6424195	total: 4.7s	remaining: 7.84s
# 375:	learn: 1.6422177	total: 4.71s	remaining: 7.82s
# 376:	learn: 1.6403957	total: 4.72s	remaining: 7.8s
# 377:	learn: 1.6393311	total: 4.73s	remaining: 7.78s
# 378:	learn: 1.6393064	total: 4.74s	remaining: 7.76s
# 379:	learn: 1.6391022	total: 4.75s	remaining: 7.76s
# 380:	learn: 1.6385605	total: 4.78s	remaining: 7.76s
# 381:	learn: 1.6376027	total: 4.79s	remaining: 7.75s
# 382:	learn: 1.6369548	total: 4.8s	remaining: 7.73s
# 383:	learn: 1.6367958	total: 4.81s	remaining: 7.71s
# 384:	learn: 1.6366111	total: 4.82s	remaining: 7.7s
# 385:	learn: 1.6357881	total: 4.83s	remaining: 7.69s
# 386:	learn: 1.6357175	total: 4.84s	remaining: 7.67s
# 387:	learn: 1.6354563	total: 4.85s	remaining: 7.66s
# 388:	learn: 1.6333318	total: 4.86s	remaining: 7.64s
# 389:	learn: 1.6332273	total: 4.87s	remaining: 7.62s
# 390:	learn: 1.6325961	total: 4.88s	remaining: 7.6s
# 391:	learn: 1.6325917	total: 4.88s	remaining: 7.58s
# 392:	learn: 1.6325697	total: 4.89s	remaining: 7.55s
# 393:	learn: 1.6324500	total: 4.9s	remaining: 7.54s
# 394:	learn: 1.6313049	total: 4.91s	remaining: 7.52s
# 395:	learn: 1.6312731	total: 4.91s	remaining: 7.5s
# 396:	learn: 1.6311846	total: 4.92s	remaining: 7.48s
# 397:	learn: 1.6311780	total: 4.93s	remaining: 7.46s
# 398:	learn: 1.6311271	total: 4.94s	remaining: 7.44s
# 399:	learn: 1.6309771	total: 4.96s	remaining: 7.43s
# 400:	learn: 1.6277064	total: 4.98s	remaining: 7.43s
# 401:	learn: 1.6270991	total: 4.98s	remaining: 7.41s
# 402:	learn: 1.6265713	total: 4.99s	remaining: 7.39s
# 403:	learn: 1.6265183	total: 5s	remaining: 7.38s
# 404:	learn: 1.6261441	total: 5.01s	remaining: 7.37s
# 405:	learn: 1.6261347	total: 5.02s	remaining: 7.34s
# 406:	learn: 1.6260676	total: 5.03s	remaining: 7.33s
# 407:	learn: 1.6260154	total: 5.03s	remaining: 7.3s
# 408:	learn: 1.6249378	total: 5.04s	remaining: 7.29s
# 409:	learn: 1.6239735	total: 5.05s	remaining: 7.27s
# 410:	learn: 1.6238175	total: 5.07s	remaining: 7.26s
# 411:	learn: 1.6228613	total: 5.08s	remaining: 7.24s
# 412:	learn: 1.6226055	total: 5.08s	remaining: 7.22s
# 413:	learn: 1.6222328	total: 5.1s	remaining: 7.21s
# 414:	learn: 1.6215436	total: 5.11s	remaining: 7.2s
# 415:	learn: 1.6215196	total: 5.11s	remaining: 7.17s
# 416:	learn: 1.6212261	total: 5.12s	remaining: 7.16s
# 417:	learn: 1.6207605	total: 5.13s	remaining: 7.15s
# 418:	learn: 1.6207324	total: 5.14s	remaining: 7.13s
# 419:	learn: 1.6207060	total: 5.15s	remaining: 7.12s
# 420:	learn: 1.6204364	total: 5.18s	remaining: 7.12s
# 421:	learn: 1.6184274	total: 5.19s	remaining: 7.11s
# 422:	learn: 1.6181795	total: 5.21s	remaining: 7.1s
# 423:	learn: 1.6180796	total: 5.22s	remaining: 7.09s
# 424:	learn: 1.6180195	total: 5.23s	remaining: 7.07s
# 425:	learn: 1.6176244	total: 5.24s	remaining: 7.06s
# 426:	learn: 1.6158967	total: 5.25s	remaining: 7.04s
# 427:	learn: 1.6146794	total: 5.26s	remaining: 7.03s
# 428:	learn: 1.6146764	total: 5.26s	remaining: 7s
# 429:	learn: 1.6143561	total: 5.27s	remaining: 6.99s
# 430:	learn: 1.6143415	total: 5.28s	remaining: 6.97s
# 431:	learn: 1.6142654	total: 5.28s	remaining: 6.95s
# 432:	learn: 1.6139618	total: 5.29s	remaining: 6.93s
# 433:	learn: 1.6139320	total: 5.3s	remaining: 6.91s
# 434:	learn: 1.6135964	total: 5.31s	remaining: 6.9s
# 435:	learn: 1.6123588	total: 5.32s	remaining: 6.88s
# 436:	learn: 1.6123560	total: 5.32s	remaining: 6.86s
# 437:	learn: 1.6121336	total: 5.33s	remaining: 6.84s
# 438:	learn: 1.6107348	total: 5.35s	remaining: 6.83s
# 439:	learn: 1.6100570	total: 5.37s	remaining: 6.83s
# 440:	learn: 1.6100431	total: 5.38s	remaining: 6.82s
# 441:	learn: 1.6088877	total: 5.39s	remaining: 6.81s
# 442:	learn: 1.6088500	total: 5.41s	remaining: 6.8s
# 443:	learn: 1.6075748	total: 5.42s	remaining: 6.78s
# 444:	learn: 1.6075713	total: 5.42s	remaining: 6.76s
# 445:	learn: 1.6075525	total: 5.43s	remaining: 6.75s
# 446:	learn: 1.6065099	total: 5.44s	remaining: 6.73s
# 447:	learn: 1.6062839	total: 5.45s	remaining: 6.72s
# 448:	learn: 1.6062699	total: 5.46s	remaining: 6.7s
# 449:	learn: 1.6062634	total: 5.46s	remaining: 6.67s
# 450:	learn: 1.6061459	total: 5.47s	remaining: 6.66s
# 451:	learn: 1.6061262	total: 5.48s	remaining: 6.65s
# 452:	learn: 1.6061205	total: 5.49s	remaining: 6.63s
# 453:	learn: 1.6061154	total: 5.49s	remaining: 6.6s
# 454:	learn: 1.6059812	total: 5.5s	remaining: 6.59s
# 455:	learn: 1.6047642	total: 5.52s	remaining: 6.58s
# 456:	learn: 1.6046851	total: 5.53s	remaining: 6.57s
# 457:	learn: 1.6037142	total: 5.54s	remaining: 6.55s
# 458:	learn: 1.6036992	total: 5.54s	remaining: 6.54s
# 459:	learn: 1.6036565	total: 5.56s	remaining: 6.53s
# 460:	learn: 1.6035489	total: 5.58s	remaining: 6.52s
# 461:	learn: 1.6035392	total: 5.59s	remaining: 6.51s
# 462:	learn: 1.6021433	total: 5.6s	remaining: 6.5s
# 463:	learn: 1.6021420	total: 5.6s	remaining: 6.47s
# 464:	learn: 1.6014990	total: 5.62s	remaining: 6.46s
# 465:	learn: 1.6014869	total: 5.62s	remaining: 6.44s
# 466:	learn: 1.6013473	total: 5.62s	remaining: 6.42s
# 467:	learn: 1.6012579	total: 5.63s	remaining: 6.4s
# 468:	learn: 1.5991668	total: 5.65s	remaining: 6.4s
# 469:	learn: 1.5991637	total: 5.65s	remaining: 6.38s
# 470:	learn: 1.5991636	total: 5.66s	remaining: 6.35s
# 471:	learn: 1.5991635	total: 5.66s	remaining: 6.33s
# 472:	learn: 1.5990247	total: 5.67s	remaining: 6.32s
# 473:	learn: 1.5973824	total: 5.68s	remaining: 6.3s
# 474:	learn: 1.5972834	total: 5.69s	remaining: 6.29s
# 475:	learn: 1.5972794	total: 5.69s	remaining: 6.26s
# 476:	learn: 1.5972554	total: 5.7s	remaining: 6.25s
# 477:	learn: 1.5971505	total: 5.7s	remaining: 6.23s
# 478:	learn: 1.5971469	total: 5.71s	remaining: 6.21s
# 479:	learn: 1.5971446	total: 5.71s	remaining: 6.19s
# 480:	learn: 1.5967052	total: 5.72s	remaining: 6.17s
# 481:	learn: 1.5966874	total: 5.73s	remaining: 6.16s
# 482:	learn: 1.5964568	total: 5.74s	remaining: 6.14s
# 483:	learn: 1.5964340	total: 5.75s	remaining: 6.13s
# 484:	learn: 1.5964217	total: 5.76s	remaining: 6.12s
# 485:	learn: 1.5963617	total: 5.77s	remaining: 6.1s
# 486:	learn: 1.5932510	total: 5.79s	remaining: 6.1s
# 487:	learn: 1.5932127	total: 5.81s	remaining: 6.09s
# 488:	learn: 1.5923836	total: 5.82s	remaining: 6.09s
# 489:	learn: 1.5923012	total: 5.84s	remaining: 6.08s
# 490:	learn: 1.5921644	total: 5.85s	remaining: 6.06s
# 491:	learn: 1.5921316	total: 5.86s	remaining: 6.05s
# 492:	learn: 1.5921206	total: 5.87s	remaining: 6.03s
# 493:	learn: 1.5910249	total: 5.88s	remaining: 6.02s
# 494:	learn: 1.5910206	total: 5.88s	remaining: 6s
# 495:	learn: 1.5910187	total: 5.88s	remaining: 5.98s
# 496:	learn: 1.5899535	total: 5.9s	remaining: 5.97s
# 497:	learn: 1.5890296	total: 5.91s	remaining: 5.96s
# 498:	learn: 1.5885139	total: 5.92s	remaining: 5.94s
# 499:	learn: 1.5885067	total: 5.92s	remaining: 5.92s
# 500:	learn: 1.5885021	total: 5.93s	remaining: 5.91s
# 501:	learn: 1.5873839	total: 5.95s	remaining: 5.9s
# 502:	learn: 1.5873669	total: 5.96s	remaining: 5.89s
# 503:	learn: 1.5873257	total: 5.97s	remaining: 5.88s
# 504:	learn: 1.5850578	total: 6s	remaining: 5.88s
# 505:	learn: 1.5848721	total: 6s	remaining: 5.86s
# 506:	learn: 1.5848445	total: 6.01s	remaining: 5.85s
# 507:	learn: 1.5841750	total: 6.02s	remaining: 5.83s
# 508:	learn: 1.5841158	total: 6.03s	remaining: 5.81s
# 509:	learn: 1.5827728	total: 6.04s	remaining: 5.8s
# 510:	learn: 1.5820326	total: 6.04s	remaining: 5.78s
# 511:	learn: 1.5820177	total: 6.05s	remaining: 5.77s
# 512:	learn: 1.5820145	total: 6.05s	remaining: 5.75s
# 513:	learn: 1.5819787	total: 6.07s	remaining: 5.74s
# 514:	learn: 1.5819701	total: 6.07s	remaining: 5.72s
# 515:	learn: 1.5819164	total: 6.08s	remaining: 5.71s
# 516:	learn: 1.5818391	total: 6.09s	remaining: 5.69s
# 517:	learn: 1.5806801	total: 6.11s	remaining: 5.68s
# 518:	learn: 1.5806623	total: 6.12s	remaining: 5.67s
# 519:	learn: 1.5806603	total: 6.12s	remaining: 5.65s
# 520:	learn: 1.5806490	total: 6.13s	remaining: 5.64s
# 521:	learn: 1.5805253	total: 6.15s	remaining: 5.63s
# 522:	learn: 1.5805078	total: 6.16s	remaining: 5.62s
# 523:	learn: 1.5805076	total: 6.17s	remaining: 5.6s
# 524:	learn: 1.5804925	total: 6.18s	remaining: 5.59s
# 525:	learn: 1.5804811	total: 6.19s	remaining: 5.58s
# 526:	learn: 1.5799745	total: 6.21s	remaining: 5.58s
# 527:	learn: 1.5799736	total: 6.22s	remaining: 5.56s
# 528:	learn: 1.5798484	total: 6.24s	remaining: 5.56s
# 529:	learn: 1.5782876	total: 6.26s	remaining: 5.55s
# 530:	learn: 1.5782064	total: 6.27s	remaining: 5.54s
# 531:	learn: 1.5782038	total: 6.28s	remaining: 5.53s
# 532:	learn: 1.5763802	total: 6.3s	remaining: 5.52s
# 533:	learn: 1.5763526	total: 6.31s	remaining: 5.5s
# 534:	learn: 1.5747775	total: 6.32s	remaining: 5.5s
# 535:	learn: 1.5722172	total: 6.34s	remaining: 5.49s
# 536:	learn: 1.5721309	total: 6.35s	remaining: 5.48s
# 537:	learn: 1.5721206	total: 6.37s	remaining: 5.47s
# 538:	learn: 1.5716964	total: 6.39s	remaining: 5.46s
# 539:	learn: 1.5713727	total: 6.4s	remaining: 5.45s
# 540:	learn: 1.5708490	total: 6.41s	remaining: 5.44s
# 541:	learn: 1.5700822	total: 6.42s	remaining: 5.43s
# 542:	learn: 1.5700731	total: 6.44s	remaining: 5.42s
# 543:	learn: 1.5698165	total: 6.45s	remaining: 5.4s
# 544:	learn: 1.5696372	total: 6.45s	remaining: 5.39s
# 545:	learn: 1.5693236	total: 6.46s	remaining: 5.37s
# 546:	learn: 1.5683490	total: 6.47s	remaining: 5.36s
# 547:	learn: 1.5683383	total: 6.49s	remaining: 5.35s
# 548:	learn: 1.5683354	total: 6.49s	remaining: 5.33s
# 549:	learn: 1.5672674	total: 6.5s	remaining: 5.32s
# 550:	learn: 1.5672281	total: 6.52s	remaining: 5.31s
# 551:	learn: 1.5664537	total: 6.54s	remaining: 5.31s
# 552:	learn: 1.5663526	total: 6.55s	remaining: 5.29s
# 553:	learn: 1.5660970	total: 6.58s	remaining: 5.29s
# 554:	learn: 1.5658768	total: 6.59s	remaining: 5.29s
# 555:	learn: 1.5657258	total: 6.61s	remaining: 5.28s
# 556:	learn: 1.5652252	total: 6.63s	remaining: 5.27s
# 557:	learn: 1.5652233	total: 6.63s	remaining: 5.25s
# 558:	learn: 1.5652183	total: 6.64s	remaining: 5.24s
# 559:	learn: 1.5652043	total: 6.65s	remaining: 5.22s
# 560:	learn: 1.5650819	total: 6.66s	remaining: 5.21s
# 561:	learn: 1.5650686	total: 6.66s	remaining: 5.19s
# 562:	learn: 1.5646284	total: 6.67s	remaining: 5.18s
# 563:	learn: 1.5646244	total: 6.67s	remaining: 5.16s
# 564:	learn: 1.5645637	total: 6.68s	remaining: 5.15s
# 565:	learn: 1.5645384	total: 6.69s	remaining: 5.13s
# 566:	learn: 1.5642234	total: 6.7s	remaining: 5.12s
# 567:	learn: 1.5642201	total: 6.71s	remaining: 5.11s
# 568:	learn: 1.5642147	total: 6.72s	remaining: 5.09s
# 569:	learn: 1.5634203	total: 6.74s	remaining: 5.08s
# 570:	learn: 1.5634150	total: 6.74s	remaining: 5.07s
# 571:	learn: 1.5634090	total: 6.75s	remaining: 5.05s
# 572:	learn: 1.5633568	total: 6.76s	remaining: 5.04s
# 573:	learn: 1.5633096	total: 6.78s	remaining: 5.03s
# 574:	learn: 1.5633062	total: 6.78s	remaining: 5.01s
# 575:	learn: 1.5605884	total: 6.8s	remaining: 5s
# 576:	learn: 1.5598890	total: 6.82s	remaining: 5s
# 577:	learn: 1.5598659	total: 6.83s	remaining: 4.98s
# 578:	learn: 1.5598360	total: 6.83s	remaining: 4.97s
# 579:	learn: 1.5595888	total: 6.84s	remaining: 4.95s
# 580:	learn: 1.5586378	total: 6.85s	remaining: 4.94s
# 581:	learn: 1.5586262	total: 6.86s	remaining: 4.93s
# 582:	learn: 1.5584644	total: 6.87s	remaining: 4.91s
# 583:	learn: 1.5584135	total: 6.88s	remaining: 4.9s
# 584:	learn: 1.5583597	total: 6.88s	remaining: 4.88s
# 585:	learn: 1.5581544	total: 6.89s	remaining: 4.87s
# 586:	learn: 1.5581489	total: 6.9s	remaining: 4.85s
# 587:	learn: 1.5580029	total: 6.91s	remaining: 4.84s
# 588:	learn: 1.5580012	total: 6.91s	remaining: 4.82s
# 589:	learn: 1.5577191	total: 6.92s	remaining: 4.81s
# 590:	learn: 1.5571796	total: 6.93s	remaining: 4.8s
# 591:	learn: 1.5571796	total: 6.93s	remaining: 4.78s
# 592:	learn: 1.5570289	total: 6.95s	remaining: 4.77s
# 593:	learn: 1.5570092	total: 6.97s	remaining: 4.76s
# 594:	learn: 1.5570031	total: 6.98s	remaining: 4.75s
# 595:	learn: 1.5569889	total: 6.99s	remaining: 4.74s
# 596:	learn: 1.5568103	total: 7.01s	remaining: 4.73s
# 597:	learn: 1.5567553	total: 7.02s	remaining: 4.72s
# 598:	learn: 1.5567359	total: 7.03s	remaining: 4.71s
# 599:	learn: 1.5567307	total: 7.04s	remaining: 4.69s
# 600:	learn: 1.5567284	total: 7.04s	remaining: 4.67s
# 601:	learn: 1.5566288	total: 7.05s	remaining: 4.66s
# 602:	learn: 1.5566269	total: 7.05s	remaining: 4.64s
# 603:	learn: 1.5565897	total: 7.07s	remaining: 4.64s
# 604:	learn: 1.5564919	total: 7.08s	remaining: 4.62s
# 605:	learn: 1.5564845	total: 7.09s	remaining: 4.61s
# 606:	learn: 1.5563429	total: 7.09s	remaining: 4.59s
# 607:	learn: 1.5562958	total: 7.11s	remaining: 4.58s
# 608:	learn: 1.5556778	total: 7.12s	remaining: 4.57s
# 609:	learn: 1.5556051	total: 7.12s	remaining: 4.55s
# 610:	learn: 1.5556032	total: 7.13s	remaining: 4.54s
# 611:	learn: 1.5548470	total: 7.14s	remaining: 4.53s
# 612:	learn: 1.5534001	total: 7.15s	remaining: 4.52s
# 613:	learn: 1.5533982	total: 7.16s	remaining: 4.5s
# 614:	learn: 1.5532839	total: 7.18s	remaining: 4.49s
# 615:	learn: 1.5532642	total: 7.2s	remaining: 4.49s
# 616:	learn: 1.5532623	total: 7.2s	remaining: 4.47s
# 617:	learn: 1.5532518	total: 7.21s	remaining: 4.46s
# 618:	learn: 1.5530955	total: 7.22s	remaining: 4.44s
# 619:	learn: 1.5530182	total: 7.23s	remaining: 4.43s
# 620:	learn: 1.5528966	total: 7.24s	remaining: 4.42s
# 621:	learn: 1.5528927	total: 7.25s	remaining: 4.4s
# 622:	learn: 1.5527270	total: 7.26s	remaining: 4.39s
# 623:	learn: 1.5527086	total: 7.27s	remaining: 4.38s
# 624:	learn: 1.5507975	total: 7.28s	remaining: 4.37s
# 625:	learn: 1.5506911	total: 7.29s	remaining: 4.36s
# 626:	learn: 1.5493159	total: 7.31s	remaining: 4.35s
# 627:	learn: 1.5492377	total: 7.33s	remaining: 4.34s
# 628:	learn: 1.5490135	total: 7.35s	remaining: 4.33s
# 629:	learn: 1.5490128	total: 7.35s	remaining: 4.32s
# 630:	learn: 1.5490106	total: 7.36s	remaining: 4.3s
# 631:	learn: 1.5490105	total: 7.36s	remaining: 4.29s
# 632:	learn: 1.5489249	total: 7.38s	remaining: 4.28s
# 633:	learn: 1.5483904	total: 7.42s	remaining: 4.28s
# 634:	learn: 1.5479225	total: 7.44s	remaining: 4.28s
# 635:	learn: 1.5478082	total: 7.46s	remaining: 4.27s
# 636:	learn: 1.5478082	total: 7.46s	remaining: 4.25s
# 637:	learn: 1.5478074	total: 7.46s	remaining: 4.24s
# 638:	learn: 1.5478034	total: 7.47s	remaining: 4.22s
# 639:	learn: 1.5476818	total: 7.49s	remaining: 4.21s
# 640:	learn: 1.5476760	total: 7.49s	remaining: 4.19s
# 641:	learn: 1.5473934	total: 7.5s	remaining: 4.18s
# 642:	learn: 1.5472593	total: 7.51s	remaining: 4.17s
# 643:	learn: 1.5472545	total: 7.51s	remaining: 4.15s
# 644:	learn: 1.5470162	total: 7.53s	remaining: 4.14s
# 645:	learn: 1.5468489	total: 7.54s	remaining: 4.13s
# 646:	learn: 1.5468467	total: 7.55s	remaining: 4.12s
# 647:	learn: 1.5458664	total: 7.57s	remaining: 4.11s
# 648:	learn: 1.5458604	total: 7.58s	remaining: 4.1s
# 649:	learn: 1.5457171	total: 7.6s	remaining: 4.09s
# 650:	learn: 1.5457128	total: 7.62s	remaining: 4.08s
# 651:	learn: 1.5455177	total: 7.63s	remaining: 4.07s
# 652:	learn: 1.5451863	total: 7.64s	remaining: 4.06s
# 653:	learn: 1.5451812	total: 7.65s	remaining: 4.05s
# 654:	learn: 1.5441330	total: 7.66s	remaining: 4.04s
# 655:	learn: 1.5440553	total: 7.67s	remaining: 4.02s
# 656:	learn: 1.5440552	total: 7.67s	remaining: 4.01s
# 657:	learn: 1.5427249	total: 7.68s	remaining: 3.99s
# 658:	learn: 1.5427248	total: 7.69s	remaining: 3.98s
# 659:	learn: 1.5419326	total: 7.7s	remaining: 3.96s
# 660:	learn: 1.5419291	total: 7.7s	remaining: 3.95s
# 661:	learn: 1.5418139	total: 7.71s	remaining: 3.94s
# 662:	learn: 1.5418130	total: 7.72s	remaining: 3.92s
# 663:	learn: 1.5406114	total: 7.73s	remaining: 3.91s
# 664:	learn: 1.5406109	total: 7.73s	remaining: 3.89s
# 665:	learn: 1.5404027	total: 7.74s	remaining: 3.88s
# 666:	learn: 1.5397833	total: 7.75s	remaining: 3.87s
# 667:	learn: 1.5397371	total: 7.77s	remaining: 3.86s
# 668:	learn: 1.5397351	total: 7.77s	remaining: 3.85s
# 669:	learn: 1.5397347	total: 7.78s	remaining: 3.83s
# 670:	learn: 1.5397334	total: 7.79s	remaining: 3.82s
# 671:	learn: 1.5397331	total: 7.8s	remaining: 3.81s
# 672:	learn: 1.5397326	total: 7.81s	remaining: 3.79s
# 673:	learn: 1.5385831	total: 7.82s	remaining: 3.78s
# 674:	learn: 1.5384670	total: 7.83s	remaining: 3.77s
# 675:	learn: 1.5376616	total: 7.84s	remaining: 3.76s
# 676:	learn: 1.5376472	total: 7.84s	remaining: 3.74s
# 677:	learn: 1.5376439	total: 7.85s	remaining: 3.73s
# 678:	learn: 1.5363290	total: 7.87s	remaining: 3.72s
# 679:	learn: 1.5362711	total: 7.87s	remaining: 3.71s
# 680:	learn: 1.5359257	total: 7.88s	remaining: 3.69s
# 681:	learn: 1.5359231	total: 7.89s	remaining: 3.68s
# 682:	learn: 1.5359230	total: 7.89s	remaining: 3.66s
# 683:	learn: 1.5359221	total: 7.89s	remaining: 3.65s
# 684:	learn: 1.5355019	total: 7.9s	remaining: 3.63s
# 685:	learn: 1.5355008	total: 7.91s	remaining: 3.62s
# 686:	learn: 1.5354250	total: 7.92s	remaining: 3.61s
# 687:	learn: 1.5345458	total: 7.93s	remaining: 3.6s
# 688:	learn: 1.5345327	total: 7.94s	remaining: 3.58s
# 689:	learn: 1.5343938	total: 7.95s	remaining: 3.57s
# 690:	learn: 1.5343901	total: 7.96s	remaining: 3.56s
# 691:	learn: 1.5343872	total: 7.97s	remaining: 3.55s
# 692:	learn: 1.5343842	total: 7.98s	remaining: 3.54s
# 693:	learn: 1.5340900	total: 8s	remaining: 3.53s
# 694:	learn: 1.5335474	total: 8.02s	remaining: 3.52s
# 695:	learn: 1.5335149	total: 8.03s	remaining: 3.51s
# 696:	learn: 1.5329903	total: 8.04s	remaining: 3.5s
# 697:	learn: 1.5329877	total: 8.04s	remaining: 3.48s
# 698:	learn: 1.5320076	total: 8.05s	remaining: 3.47s
# 699:	learn: 1.5320048	total: 8.06s	remaining: 3.45s
# 700:	learn: 1.5295962	total: 8.07s	remaining: 3.44s
# 701:	learn: 1.5295962	total: 8.07s	remaining: 3.43s
# 702:	learn: 1.5289534	total: 8.09s	remaining: 3.42s
# 703:	learn: 1.5283488	total: 8.09s	remaining: 3.4s
# 704:	learn: 1.5283462	total: 8.1s	remaining: 3.39s
# 705:	learn: 1.5276744	total: 8.11s	remaining: 3.38s
# 706:	learn: 1.5269775	total: 8.12s	remaining: 3.36s
# 707:	learn: 1.5269767	total: 8.12s	remaining: 3.35s
# 708:	learn: 1.5269706	total: 8.13s	remaining: 3.33s
# 709:	learn: 1.5269684	total: 8.13s	remaining: 3.32s
# 710:	learn: 1.5268544	total: 8.14s	remaining: 3.31s
# 711:	learn: 1.5268106	total: 8.16s	remaining: 3.3s
# 712:	learn: 1.5266587	total: 8.18s	remaining: 3.29s
# 713:	learn: 1.5266556	total: 8.2s	remaining: 3.28s
# 714:	learn: 1.5266550	total: 8.2s	remaining: 3.27s
# 715:	learn: 1.5264800	total: 8.21s	remaining: 3.26s
# 716:	learn: 1.5264797	total: 8.21s	remaining: 3.24s
# 717:	learn: 1.5263638	total: 8.22s	remaining: 3.23s
# 718:	learn: 1.5263638	total: 8.23s	remaining: 3.21s
# 719:	learn: 1.5256288	total: 8.24s	remaining: 3.2s
# 720:	learn: 1.5256085	total: 8.25s	remaining: 3.19s
# 721:	learn: 1.5256079	total: 8.25s	remaining: 3.18s
# 722:	learn: 1.5242619	total: 8.26s	remaining: 3.17s
# 723:	learn: 1.5242213	total: 8.28s	remaining: 3.15s
# 724:	learn: 1.5234446	total: 8.29s	remaining: 3.14s
# 725:	learn: 1.5233019	total: 8.31s	remaining: 3.14s
# 726:	learn: 1.5231859	total: 8.33s	remaining: 3.13s
# 727:	learn: 1.5231850	total: 8.34s	remaining: 3.11s
# 728:	learn: 1.5231842	total: 8.35s	remaining: 3.1s
# 729:	learn: 1.5231837	total: 8.36s	remaining: 3.09s
# 730:	learn: 1.5231700	total: 8.37s	remaining: 3.08s
# 731:	learn: 1.5231687	total: 8.38s	remaining: 3.07s
# 732:	learn: 1.5231118	total: 8.4s	remaining: 3.06s
# 733:	learn: 1.5229910	total: 8.42s	remaining: 3.05s
# 734:	learn: 1.5229762	total: 8.42s	remaining: 3.04s
# 735:	learn: 1.5229761	total: 8.42s	remaining: 3.02s
# 736:	learn: 1.5229760	total: 8.43s	remaining: 3.01s
# 737:	learn: 1.5229754	total: 8.43s	remaining: 2.99s
# 738:	learn: 1.5229752	total: 8.44s	remaining: 2.98s
# 739:	learn: 1.5229747	total: 8.44s	remaining: 2.96s
# 740:	learn: 1.5229734	total: 8.44s	remaining: 2.95s
# 741:	learn: 1.5225946	total: 8.45s	remaining: 2.94s
# 742:	learn: 1.5225939	total: 8.46s	remaining: 2.92s
# 743:	learn: 1.5225908	total: 8.46s	remaining: 2.91s
# 744:	learn: 1.5225485	total: 8.48s	remaining: 2.9s
# 745:	learn: 1.5225448	total: 8.48s	remaining: 2.89s
# 746:	learn: 1.5225444	total: 8.49s	remaining: 2.88s
# 747:	learn: 1.5213811	total: 8.5s	remaining: 2.86s
# 748:	learn: 1.5213761	total: 8.51s	remaining: 2.85s
# 749:	learn: 1.5192681	total: 8.52s	remaining: 2.84s
# 750:	learn: 1.5191991	total: 8.53s	remaining: 2.83s
# 751:	learn: 1.5191984	total: 8.54s	remaining: 2.82s
# 752:	learn: 1.5188530	total: 8.56s	remaining: 2.81s
# 753:	learn: 1.5187998	total: 8.57s	remaining: 2.79s
# 754:	learn: 1.5185907	total: 8.58s	remaining: 2.79s
# 755:	learn: 1.5185873	total: 8.6s	remaining: 2.77s
# 756:	learn: 1.5185854	total: 8.61s	remaining: 2.76s
# 757:	learn: 1.5185708	total: 8.62s	remaining: 2.75s
# 758:	learn: 1.5185558	total: 8.63s	remaining: 2.74s
# 759:	learn: 1.5178532	total: 8.64s	remaining: 2.73s
# 760:	learn: 1.5178485	total: 8.65s	remaining: 2.72s
# 761:	learn: 1.5178484	total: 8.66s	remaining: 2.7s
# 762:	learn: 1.5171747	total: 8.67s	remaining: 2.69s
# 763:	learn: 1.5171732	total: 8.67s	remaining: 2.68s
# 764:	learn: 1.5165627	total: 8.68s	remaining: 2.67s
# 765:	learn: 1.5165613	total: 8.69s	remaining: 2.65s
# 766:	learn: 1.5165606	total: 8.7s	remaining: 2.64s
# 767:	learn: 1.5165605	total: 8.7s	remaining: 2.63s
# 768:	learn: 1.5164659	total: 8.71s	remaining: 2.62s
# 769:	learn: 1.5164655	total: 8.71s	remaining: 2.6s
# 770:	learn: 1.5164646	total: 8.72s	remaining: 2.59s
# 771:	learn: 1.5161774	total: 8.73s	remaining: 2.58s
# 772:	learn: 1.5155666	total: 8.75s	remaining: 2.57s
# 773:	learn: 1.5155664	total: 8.76s	remaining: 2.56s
# 774:	learn: 1.5154398	total: 8.77s	remaining: 2.55s
# 775:	learn: 1.5153509	total: 8.8s	remaining: 2.54s
# 776:	learn: 1.5153507	total: 8.81s	remaining: 2.53s
# 777:	learn: 1.5153443	total: 8.82s	remaining: 2.52s
# 778:	learn: 1.5153417	total: 8.83s	remaining: 2.5s
# 779:	learn: 1.5153378	total: 8.84s	remaining: 2.49s
# 780:	learn: 1.5152805	total: 8.85s	remaining: 2.48s
# 781:	learn: 1.5152568	total: 8.86s	remaining: 2.47s
# 782:	learn: 1.5151149	total: 8.87s	remaining: 2.46s
# 783:	learn: 1.5143374	total: 8.89s	remaining: 2.45s
# 784:	learn: 1.5143334	total: 8.89s	remaining: 2.43s
# 785:	learn: 1.5137347	total: 8.9s	remaining: 2.42s
# 786:	learn: 1.5137314	total: 8.91s	remaining: 2.41s
# 787:	learn: 1.5127294	total: 8.92s	remaining: 2.4s
# 788:	learn: 1.5125729	total: 8.93s	remaining: 2.39s
# 789:	learn: 1.5125632	total: 8.94s	remaining: 2.38s
# 790:	learn: 1.5124779	total: 8.96s	remaining: 2.37s
# 791:	learn: 1.5124778	total: 8.97s	remaining: 2.35s
# 792:	learn: 1.5124741	total: 8.99s	remaining: 2.35s
# 793:	learn: 1.5123477	total: 9.01s	remaining: 2.34s
# 794:	learn: 1.5123446	total: 9.02s	remaining: 2.33s
# 795:	learn: 1.5123438	total: 9.02s	remaining: 2.31s
# 796:	learn: 1.5104574	total: 9.03s	remaining: 2.3s
# 797:	learn: 1.5104477	total: 9.04s	remaining: 2.29s
# 798:	learn: 1.5103248	total: 9.05s	remaining: 2.28s
# 799:	learn: 1.5103245	total: 9.05s	remaining: 2.26s
# 800:	learn: 1.5097816	total: 9.06s	remaining: 2.25s
# 801:	learn: 1.5097807	total: 9.07s	remaining: 2.24s
# 802:	learn: 1.5097806	total: 9.07s	remaining: 2.23s
# 803:	learn: 1.5093167	total: 9.08s	remaining: 2.21s
# 804:	learn: 1.5093167	total: 9.09s	remaining: 2.2s
# 805:	learn: 1.5093164	total: 9.09s	remaining: 2.19s
# 806:	learn: 1.5092310	total: 9.1s	remaining: 2.18s
# 807:	learn: 1.5092309	total: 9.11s	remaining: 2.16s
# 808:	learn: 1.5089766	total: 9.12s	remaining: 2.15s
# 809:	learn: 1.5085206	total: 9.13s	remaining: 2.14s
# 810:	learn: 1.5085202	total: 9.14s	remaining: 2.13s
# 811:	learn: 1.5075071	total: 9.16s	remaining: 2.12s
# 812:	learn: 1.5074823	total: 9.17s	remaining: 2.11s
# 813:	learn: 1.5074813	total: 9.19s	remaining: 2.1s
# 814:	learn: 1.5074810	total: 9.2s	remaining: 2.09s
# 815:	learn: 1.5074604	total: 9.21s	remaining: 2.08s
# 816:	learn: 1.5061843	total: 9.22s	remaining: 2.06s
# 817:	learn: 1.5061550	total: 9.23s	remaining: 2.05s
# 818:	learn: 1.5061546	total: 9.23s	remaining: 2.04s
# 819:	learn: 1.5060204	total: 9.24s	remaining: 2.03s
# 820:	learn: 1.5060036	total: 9.25s	remaining: 2.02s
# 821:	learn: 1.5059622	total: 9.26s	remaining: 2s
# 822:	learn: 1.5054641	total: 9.27s	remaining: 1.99s
# 823:	learn: 1.5053328	total: 9.28s	remaining: 1.98s
# 824:	learn: 1.5053328	total: 9.28s	remaining: 1.97s
# 825:	learn: 1.5053327	total: 9.28s	remaining: 1.96s
# 826:	learn: 1.5053313	total: 9.29s	remaining: 1.94s
# 827:	learn: 1.5051835	total: 9.3s	remaining: 1.93s
# 828:	learn: 1.5051834	total: 9.3s	remaining: 1.92s
# 829:	learn: 1.5051833	total: 9.31s	remaining: 1.91s
# 830:	learn: 1.5050647	total: 9.32s	remaining: 1.89s
# 831:	learn: 1.5050547	total: 9.33s	remaining: 1.88s
# 832:	learn: 1.5050547	total: 9.34s	remaining: 1.87s
# 833:	learn: 1.5050543	total: 9.35s	remaining: 1.86s
# 834:	learn: 1.5050523	total: 9.36s	remaining: 1.85s
# 835:	learn: 1.5031402	total: 9.41s	remaining: 1.84s
# 836:	learn: 1.5031398	total: 9.42s	remaining: 1.83s
# 837:	learn: 1.5025007	total: 9.45s	remaining: 1.83s
# 838:	learn: 1.5024873	total: 9.46s	remaining: 1.81s
# 839:	learn: 1.5024869	total: 9.46s	remaining: 1.8s
# 840:	learn: 1.5024396	total: 9.47s	remaining: 1.79s
# 841:	learn: 1.5024380	total: 9.48s	remaining: 1.78s
# 842:	learn: 1.5024374	total: 9.48s	remaining: 1.77s
# 843:	learn: 1.5024372	total: 9.49s	remaining: 1.75s
# 844:	learn: 1.5002768	total: 9.5s	remaining: 1.74s
# 845:	learn: 1.5002243	total: 9.51s	remaining: 1.73s
# 846:	learn: 1.4988776	total: 9.52s	remaining: 1.72s
# 847:	learn: 1.4969253	total: 9.53s	remaining: 1.71s
# 848:	learn: 1.4969250	total: 9.54s	remaining: 1.7s
# 849:	learn: 1.4969241	total: 9.55s	remaining: 1.69s
# 850:	learn: 1.4950298	total: 9.57s	remaining: 1.67s
# 851:	learn: 1.4948534	total: 9.59s	remaining: 1.67s
# 852:	learn: 1.4927815	total: 9.6s	remaining: 1.65s
# 853:	learn: 1.4927815	total: 9.61s	remaining: 1.64s
# 854:	learn: 1.4927815	total: 9.61s	remaining: 1.63s
# 855:	learn: 1.4925808	total: 9.62s	remaining: 1.62s
# 856:	learn: 1.4925804	total: 9.63s	remaining: 1.61s
# 857:	learn: 1.4925494	total: 9.63s	remaining: 1.59s
# 858:	learn: 1.4925493	total: 9.64s	remaining: 1.58s
# 859:	learn: 1.4925493	total: 9.64s	remaining: 1.57s
# 860:	learn: 1.4924675	total: 9.65s	remaining: 1.56s
# 861:	learn: 1.4923525	total: 9.66s	remaining: 1.55s
# 862:	learn: 1.4923521	total: 9.67s	remaining: 1.53s
# 863:	learn: 1.4923482	total: 9.68s	remaining: 1.52s
# 864:	learn: 1.4918146	total: 9.69s	remaining: 1.51s
# 865:	learn: 1.4917848	total: 9.71s	remaining: 1.5s
# 866:	learn: 1.4917104	total: 9.71s	remaining: 1.49s
# 867:	learn: 1.4917025	total: 9.72s	remaining: 1.48s
# 868:	learn: 1.4916627	total: 9.73s	remaining: 1.47s
# 869:	learn: 1.4916615	total: 9.75s	remaining: 1.46s
# 870:	learn: 1.4912270	total: 9.77s	remaining: 1.45s
# 871:	learn: 1.4912259	total: 9.79s	remaining: 1.44s
# 872:	learn: 1.4912256	total: 9.8s	remaining: 1.43s
# 873:	learn: 1.4912089	total: 9.81s	remaining: 1.41s
# 874:	learn: 1.4912072	total: 9.82s	remaining: 1.4s
# 875:	learn: 1.4912061	total: 9.82s	remaining: 1.39s
# 876:	learn: 1.4912045	total: 9.83s	remaining: 1.38s
# 877:	learn: 1.4912040	total: 9.83s	remaining: 1.37s
# 878:	learn: 1.4912039	total: 9.84s	remaining: 1.35s
# 879:	learn: 1.4912039	total: 9.84s	remaining: 1.34s
# 880:	learn: 1.4911914	total: 9.85s	remaining: 1.33s
# 881:	learn: 1.4911912	total: 9.86s	remaining: 1.32s
# 882:	learn: 1.4911897	total: 9.87s	remaining: 1.31s
# 883:	learn: 1.4911870	total: 9.88s	remaining: 1.3s
# 884:	learn: 1.4911316	total: 9.88s	remaining: 1.28s
# 885:	learn: 1.4911316	total: 9.88s	remaining: 1.27s
# 886:	learn: 1.4894086	total: 9.9s	remaining: 1.26s
# 887:	learn: 1.4894076	total: 9.91s	remaining: 1.25s
# 888:	learn: 1.4894075	total: 9.91s	remaining: 1.24s
# 889:	learn: 1.4893297	total: 9.93s	remaining: 1.23s
# 890:	learn: 1.4893294	total: 9.94s	remaining: 1.22s
# 891:	learn: 1.4893291	total: 9.95s	remaining: 1.21s
# 892:	learn: 1.4893284	total: 9.97s	remaining: 1.19s
# 893:	learn: 1.4893283	total: 9.98s	remaining: 1.18s
# 894:	learn: 1.4893266	total: 9.99s	remaining: 1.17s
# 895:	learn: 1.4890672	total: 10s	remaining: 1.16s
# 896:	learn: 1.4883220	total: 10s	remaining: 1.15s
# 897:	learn: 1.4881995	total: 10s	remaining: 1.14s
# 898:	learn: 1.4877597	total: 10s	remaining: 1.13s
# 899:	learn: 1.4877593	total: 10s	remaining: 1.12s
# 900:	learn: 1.4867726	total: 10.1s	remaining: 1.1s
# 901:	learn: 1.4866744	total: 10.1s	remaining: 1.09s
# 902:	learn: 1.4866743	total: 10.1s	remaining: 1.08s
# 903:	learn: 1.4866715	total: 10.1s	remaining: 1.07s
# 904:	learn: 1.4859506	total: 10.1s	remaining: 1.06s
# 905:	learn: 1.4859337	total: 10.1s	remaining: 1.05s
# 906:	learn: 1.4859325	total: 10.1s	remaining: 1.03s
# 907:	learn: 1.4858015	total: 10.1s	remaining: 1.02s
# 908:	learn: 1.4854632	total: 10.1s	remaining: 1.01s
# 909:	learn: 1.4854632	total: 10.1s	remaining: 1s
# 910:	learn: 1.4845528	total: 10.1s	remaining: 990ms
# 911:	learn: 1.4845419	total: 10.1s	remaining: 979ms
# 912:	learn: 1.4845289	total: 10.2s	remaining: 969ms
# 913:	learn: 1.4845284	total: 10.2s	remaining: 958ms
# 914:	learn: 1.4835689	total: 10.2s	remaining: 947ms
# 915:	learn: 1.4834878	total: 10.2s	remaining: 935ms
# 916:	learn: 1.4833739	total: 10.2s	remaining: 924ms
# 917:	learn: 1.4833736	total: 10.2s	remaining: 912ms
# 918:	learn: 1.4833709	total: 10.2s	remaining: 900ms
# 919:	learn: 1.4833673	total: 10.2s	remaining: 889ms
# 920:	learn: 1.4833242	total: 10.2s	remaining: 878ms
# 921:	learn: 1.4832290	total: 10.2s	remaining: 866ms
# 922:	learn: 1.4832252	total: 10.2s	remaining: 855ms
# 923:	learn: 1.4832233	total: 10.3s	remaining: 844ms
# 924:	learn: 1.4832213	total: 10.3s	remaining: 832ms
# 925:	learn: 1.4830225	total: 10.3s	remaining: 821ms
# 926:	learn: 1.4830224	total: 10.3s	remaining: 809ms
# 927:	learn: 1.4830222	total: 10.3s	remaining: 798ms
# 928:	learn: 1.4830221	total: 10.3s	remaining: 786ms
# 929:	learn: 1.4829376	total: 10.3s	remaining: 776ms
# 930:	learn: 1.4829376	total: 10.3s	remaining: 765ms
# 931:	learn: 1.4829371	total: 10.3s	remaining: 754ms
# 932:	learn: 1.4828816	total: 10.3s	remaining: 743ms
# 933:	learn: 1.4827879	total: 10.4s	remaining: 732ms
# 934:	learn: 1.4827790	total: 10.4s	remaining: 722ms
# 935:	learn: 1.4827789	total: 10.4s	remaining: 710ms
# 936:	learn: 1.4827775	total: 10.4s	remaining: 699ms
# 937:	learn: 1.4827772	total: 10.4s	remaining: 687ms
# 938:	learn: 1.4827766	total: 10.4s	remaining: 676ms
# 939:	learn: 1.4825877	total: 10.4s	remaining: 665ms
# 940:	learn: 1.4825875	total: 10.4s	remaining: 653ms
# 941:	learn: 1.4813801	total: 10.4s	remaining: 642ms
# 942:	learn: 1.4813793	total: 10.4s	remaining: 631ms
# 943:	learn: 1.4808009	total: 10.4s	remaining: 620ms
# 944:	learn: 1.4808002	total: 10.4s	remaining: 608ms
# 945:	learn: 1.4807708	total: 10.5s	remaining: 597ms
# 946:	learn: 1.4799500	total: 10.5s	remaining: 586ms
# 947:	learn: 1.4799472	total: 10.5s	remaining: 575ms
# 948:	learn: 1.4799239	total: 10.5s	remaining: 563ms
# 949:	learn: 1.4798788	total: 10.5s	remaining: 552ms
# 950:	learn: 1.4798779	total: 10.5s	remaining: 541ms
# 951:	learn: 1.4798779	total: 10.5s	remaining: 530ms
# 952:	learn: 1.4798563	total: 10.5s	remaining: 519ms
# 953:	learn: 1.4788382	total: 10.5s	remaining: 508ms
# 954:	learn: 1.4788377	total: 10.5s	remaining: 497ms
# 955:	learn: 1.4788375	total: 10.6s	remaining: 486ms
# 956:	learn: 1.4788372	total: 10.6s	remaining: 475ms
# 957:	learn: 1.4784913	total: 10.6s	remaining: 464ms
# 958:	learn: 1.4776964	total: 10.6s	remaining: 453ms
# 959:	learn: 1.4776904	total: 10.6s	remaining: 442ms
# 960:	learn: 1.4776903	total: 10.6s	remaining: 430ms
# 961:	learn: 1.4776901	total: 10.6s	remaining: 419ms
# 962:	learn: 1.4776890	total: 10.6s	remaining: 408ms
# 963:	learn: 1.4776644	total: 10.6s	remaining: 397ms
# 964:	learn: 1.4776423	total: 10.6s	remaining: 385ms
# 965:	learn: 1.4776415	total: 10.6s	remaining: 374ms
# 966:	learn: 1.4776409	total: 10.6s	remaining: 363ms
# 967:	learn: 1.4775711	total: 10.6s	remaining: 352ms
# 968:	learn: 1.4775693	total: 10.7s	remaining: 341ms
# 969:	learn: 1.4772512	total: 10.7s	remaining: 330ms
# 970:	learn: 1.4772510	total: 10.7s	remaining: 319ms
# 971:	learn: 1.4771793	total: 10.7s	remaining: 308ms
# 972:	learn: 1.4771790	total: 10.7s	remaining: 297ms
# 973:	learn: 1.4771790	total: 10.7s	remaining: 285ms
# 974:	learn: 1.4771535	total: 10.7s	remaining: 274ms
# 975:	learn: 1.4771331	total: 10.7s	remaining: 263ms
# 976:	learn: 1.4765791	total: 10.7s	remaining: 252ms
# 977:	learn: 1.4765392	total: 10.7s	remaining: 242ms
# 978:	learn: 1.4765380	total: 10.8s	remaining: 231ms
# 979:	learn: 1.4765372	total: 10.8s	remaining: 220ms
# 980:	learn: 1.4758975	total: 10.8s	remaining: 209ms
# 981:	learn: 1.4758936	total: 10.8s	remaining: 198ms
# 982:	learn: 1.4758841	total: 10.8s	remaining: 187ms
# 983:	learn: 1.4747659	total: 10.8s	remaining: 176ms
# 984:	learn: 1.4747307	total: 10.8s	remaining: 165ms
# 985:	learn: 1.4745636	total: 10.8s	remaining: 154ms
# 986:	learn: 1.4745636	total: 10.8s	remaining: 143ms
# 987:	learn: 1.4728273	total: 10.8s	remaining: 132ms
# 988:	learn: 1.4727887	total: 10.8s	remaining: 121ms
# 989:	learn: 1.4727683	total: 10.9s	remaining: 110ms
# 990:	learn: 1.4727500	total: 10.9s	remaining: 98.7ms
# 991:	learn: 1.4727499	total: 10.9s	remaining: 87.6ms
# 992:	learn: 1.4727487	total: 10.9s	remaining: 76.6ms
# 993:	learn: 1.4727365	total: 10.9s	remaining: 65.6ms
# 994:	learn: 1.4726137	total: 10.9s	remaining: 54.7ms
# 995:	learn: 1.4721945	total: 10.9s	remaining: 43.8ms
# 996:	learn: 1.4721451	total: 10.9s	remaining: 32.9ms
# 997:	learn: 1.4721420	total: 10.9s	remaining: 21.9ms
# 998:	learn: 1.4721419	total: 10.9s	remaining: 11ms
# 999:	learn: 1.4719965	total: 11s	remaining: 0us

# %%
# Submission #010, #11
# weight 1/2.02331
model_rf = RandomForestRegressor(n_estimators=500, max_features='auto', max_depth=8, 
                                 min_samples_leaf=0.00033, min_samples_split=0.06752)
# weight 1/1.91323
model_lgb = LGBMRegressor(n_estimators=250, min_data_in_leaf=10, learning_rate=0.10550,
                          tree_learner_type='data', max_depth=4, num_leaves=50)
# weight 1/1.86258
model_xgb = XGBRegressor(silent=True, objective='reg:linear', n_estimators=250, learning_rate=0.04639,  
                         colsample_bytree=0.63095, subsample=0.77854, max_depth=7)
# weight 1/1.92542
model_cat = CatBoostRegressor(iterations=1000, eval_metric='RMSE', early_stopping_rounds=200,
                              logging_level='Silent', depth=8, learning_rate=0.043, colsample_bylevel=0.153,
                              bagging_temperature=0.063)

# %%
model_lgb.fit(X, y)
model_cat.fit(X, y)
model_xgb.fit(X, y)

pred_lgb = model_lgb.predict(X_test)
pred_cat = model_cat.predict(X_test)
pred_xgb = model_xgb.predict(X_test)

pred = (1/1.91323 * pred_lgb + 1/1.92542 * pred_cat + 1/1.86258 * pred_xgb) / (1/1.91323 + 1/1.86258 + 1/1.92542)
submission = (np.e ** pred_xgb - 1)

# %%
# Submission #012
models = [LGBMRegressor(n_estimators=500, min_data_in_leaf=10, learning_rate=0.0100,
                        bagging_fraction=0.427, max_depth=7, num_leaves=250), 
          CatBoostRegressor(iterations=1000, eval_metric='RMSE', early_stopping_rounds=200,
                          logging_level='Silent', depth=8, learning_rate=0.043, colsample_bylevel=0.153,
                          bagging_temperature=0.063),
          XGBRegressor(silent=True, objective='reg:linear', n_estimators=500, learning_rate=0.021,  
                       colsample_bytree = 0.394, subsample = 0.466, max_depth=7)]

# %%
pred = np.zeros((X.shape[0], len(models)))
    
for i, model in enumerate(models):
    model.fit(X, y)
    pred[:, i] = model.predict(X)

pred[pred < 0] = 0
stacking = LinearRegression()
stacking.fit(pred, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred = np.zeros((X_test.shape[0], len(models)))
for i, model in enumerate(models):
    pred[:, i] = model.predict(X_test)

pred[pred < 0] = 0
submission = (np.e ** stacking.predict(pred) - 1)

# %% [markdown]
# #### Fit the model to all training dataset and make prediction

# %%
model.fit(X, y)
print(np.sqrt(mean_squared_error(model.predict(X), y)))
submission = (np.e ** model.predict(X_test) - 1)
# Out:
# 0.90695914568

# %% [markdown]
# #### Output submission file

# %%
time = datetime.datetime.now()
time = '{:4d}-{:02d}-{:02d}_{:02d}-{:02d}'.format(time.year, time.month, time.day, time.hour, time.minute)

submission = pd.DataFrame({'id': np.arange(3001, 7399), 'revenue': submission})
submission.to_csv(dataset_folder + time + '_submission.csv', index=None)

# %%
with open(dataset_folder + time + '_model.pickle', 'wb') as f:
    pickle.dump(model, f, protocol=pickle.HIGHEST_PROTOCOL)
